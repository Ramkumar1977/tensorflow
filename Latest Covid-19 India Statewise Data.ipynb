# %% [markdown]
# # Latest Covid-19 India Statewise Data
# Covid-19 India Statewise Data as on June 30, 2021

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
Latest_Covid_19_India_Status = pd.read_csv("C:\\Users\\RAMKUMAR\\Downloads\\archive(3)\\Latest Covid-19 India Status.csv")
Latest_Covid_19_India_Status.head()
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0     Maharashtra      6061404  119558     5819901  121945          1.97
# 1          Kerala      2924165  101343     2809587   13235          3.47
# 2       Karnataka      2843810   76528     2732242   35040          2.69
# 3      Tamil Nadu      2479696   38191     2408886   32619          1.54
# 4  Andhra Pradesh      1889513   38338     1838469   12706          2.03
#
#    Discharge Ratio  Death Ratio
# 0            96.02         2.01
# 1            96.08         0.45
# 2            96.08         1.23
# 3            97.14         1.32
# 4            97.30         0.67

# %%
print(Latest_Covid_19_India_Status.head())
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0     Maharashtra      6061404  119558     5819901  121945          1.97
# 1          Kerala      2924165  101343     2809587   13235          3.47
# 2       Karnataka      2843810   76528     2732242   35040          2.69
# 3      Tamil Nadu      2479696   38191     2408886   32619          1.54
# 4  Andhra Pradesh      1889513   38338     1838469   12706          2.03
#
#    Discharge Ratio  Death Ratio
# 0            96.02         2.01
# 1            96.08         0.45
# 2            96.08         1.23
# 3            97.14         1.32
# 4            97.30         0.67

# %%
Latest_Covid_19_India_Status.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   State/UTs        36 non-null     object
#  1   Total Cases      36 non-null     int64
#  2   Active           36 non-null     int64
#  3   Discharged       36 non-null     int64
#  4   Deaths           36 non-null     int64
#  5   Active Ratio     36 non-null     float64
#  6   Discharge Ratio  36 non-null     float64
#  7   Death Ratio      36 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 2.4+ KB

# %%
Latest_Covid_19_India_Status.dtypes
# Out:
# State/UTs           object
# Total Cases          int64
# Active               int64
# Discharged           int64
# Deaths               int64
# Active Ratio       float64
# Discharge Ratio    float64
# Death Ratio        float64
# dtype: object

# %%
Latest_Covid_19_India_Status.describe()
# Out:
#         Total Cases         Active    Discharged         Deaths  Active Ratio  \
# count  3.600000e+01      36.000000  3.600000e+01      36.000000     36.000000
# mean   8.447676e+05   14534.916667  8.191366e+05   11096.083333      2.902500
# std    1.209487e+06   28312.184103  1.164892e+06   21092.496707      4.069466
# min    7.467000e+03      31.000000  7.308000e+03       4.000000      0.070000
# 25%    5.863075e+04    1422.500000  5.664575e+04     776.500000      0.407500
# 50%    4.270470e+05    2779.000000  4.085465e+05    4431.000000      1.425000
# 75%    9.629365e+05    7856.000000  9.502918e+05   12838.250000      3.252500
# max    6.061404e+06  119558.000000  5.819901e+06  121945.000000     20.550000
#
#        Discharge Ratio  Death Ratio
# count        36.000000    36.000000
# mean         95.844444     1.252778
# std           3.977242     0.567247
# min          79.000000     0.040000
# 25%          96.065000     0.927500
# 50%          97.200000     1.315000
# ...

# %%
Latest_Covid_19_India_Status.isnull()
# Out:
#     State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0       False        False   False       False   False         False
# 1       False        False   False       False   False         False
# 2       False        False   False       False   False         False
# 3       False        False   False       False   False         False
# 4       False        False   False       False   False         False
# 5       False        False   False       False   False         False
# 6       False        False   False       False   False         False
# 7       False        False   False       False   False         False
# 8       False        False   False       False   False         False
# 9       False        False   False       False   False         False
# 10      False        False   False       False   False         False
# 11      False        False   False       False   False         False
# 12      False        False   False       False   False         False
# ...

# %%
Latest_Covid_19_India_Status.isnull().any()
# Out:
# State/UTs          False
# Total Cases        False
# Active             False
# Discharged         False
# Deaths             False
# Active Ratio       False
# Discharge Ratio    False
# Death Ratio        False
# dtype: bool

# %%
Latest_Covid_19_India_Status.isnull().sum()
# Out:
# State/UTs          0
# Total Cases        0
# Active             0
# Discharged         0
# Deaths             0
# Active Ratio       0
# Discharge Ratio    0
# Death Ratio        0
# dtype: int64

# %%
sns.pairplot(Latest_Covid_19_India_Status)

# %%
Latest_Covid_19_India_Status.corr()
# Out:
#                  Total Cases    Active  Discharged    Deaths  Active Ratio  \
# Total Cases         1.000000  0.891116    0.999948  0.921018     -0.208720
# Active              0.891116  1.000000    0.887451  0.744227     -0.008724
# Discharged          0.999948  0.887451    1.000000  0.920082     -0.213189
# Deaths              0.921018  0.744227    0.920082  1.000000     -0.182777
# Active Ratio       -0.208720 -0.008724   -0.213189 -0.182777      1.000000
# Discharge Ratio     0.202694  0.020479    0.207277  0.147995     -0.990301
# Death Ratio         0.076104 -0.081117    0.076032  0.273742     -0.231545
#
#                  Discharge Ratio  Death Ratio
# Total Cases             0.202694     0.076104
# Active                  0.020479    -0.081117
# Discharged              0.207277     0.076032
# Deaths                  0.147995     0.273742
# Active Ratio           -0.990301    -0.231545
# Discharge Ratio         1.000000     0.094140
# ...

# %%
sns.heatmap(Latest_Covid_19_India_Status.corr())

# %%
plt.figure(figsize=(12,10))
sns.heatmap(Latest_Covid_19_India_Status.corr(),annot = True)
