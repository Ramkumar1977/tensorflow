# %% [markdown]
# # StudentsPerformance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
StudentsPerformance = pd.read_csv("Downloads//StudentsPerformance.csv")
StudentsPerformance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
print(StudentsPerformance.head())
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
StudentsPerformance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
StudentsPerformance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
StudentsPerformance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
StudentsPerformance.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
StudentsPerformance.isnull().any()
# Out:
# gender                         False
# race/ethnicity                 False
# parental level of education    False
# lunch                          False
# test preparation course        False
# math score                     False
# reading score                  False
# writing score                  False
# dtype: bool

# %%
StudentsPerformance.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
sns.pairplot(StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'reading score', y = 'math score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'reading score', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'math score', y = 'writing score', data = StudentsPerformance,hue = 'gender')

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'gender', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'lunch', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'race/ethnicity', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'race/ethnicity', y = 'writing score', data = StudentsPerformance,hue = 'gender')

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'parental level of education', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'parental level of education', y = 'writing score', data = StudentsPerformance,hue = 'gender')

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'test preparation course', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.jointplot(x = 'math score', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.jointplot(x = 'reading score', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.jointplot(x = 'math score', y = 'reading score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x = 'parental level of education', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x = 'parental level of education', y = 'writing score', data = StudentsPerformance,hue = 'gender')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x = 'race/ethnicity', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x = 'race/ethnicity', y = 'writing score', data = StudentsPerformance,hue = 'gender')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x = 'lunch', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x = 'lunch', y = 'writing score', data = StudentsPerformance,hue = 'gender')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x = 'test preparation course', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x = 'test preparation course', y = 'writing score', data = StudentsPerformance,hue = 'gender')

# %%
plt.figure(figsize=(12,8))
sns.catplot(x = 'test preparation course', y = 'writing score', data = StudentsPerformance,hue = 'gender')

# %%
plt.figure(figsize=(12,8))
sns.catplot(x = 'test preparation course', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.catplot(x = 'lunch', y = 'writing score', data = StudentsPerformance,hue = 'gender')

# %%
plt.figure(figsize=(12,8))
sns.catplot(x = 'lunch', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.catplot(x = 'race/ethnicity', y = 'writing score', data = StudentsPerformance,hue = 'gender')

# %%
plt.figure(figsize=(12,8))
sns.catplot(x = 'race/ethnicity', y = 'writing score', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.countplot(x = 'race/ethnicity', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.countplot(x = 'lunch', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.countplot(x = 'test preparation course', data = StudentsPerformance)

# %%
plt.figure(figsize=(12,8))
sns.countplot(x = 'parental level of education', data = StudentsPerformance)

# %%
StudentsPerformance.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
sns.heatmap(StudentsPerformance.corr())

# %%
sns.heatmap(StudentsPerformance.corr(),annot = True)
